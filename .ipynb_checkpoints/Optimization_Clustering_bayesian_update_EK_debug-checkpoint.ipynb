# %%
import pandas as pd
import numpy as np
from pandas_datareader import data, wb
from datetime import datetime
import matplotlib.pyplot as plt
from scipy import stats, integrate
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier
import bs4 as bs
import requests
import yfinance as yf
import seaborn as sns
import cvxpy as cp
from sklearn.cluster import AgglomerativeClustering
from quantstats import *

# %% [markdown]
# ## Get Universe - Current S&P 500 stocks that exhisted in 2002

# %%
"""
resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs.BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})
tickers = []
for row in table.findAll('tr')[1:]:
    ticker = row.findAll('td')[0].text
    tickers.append(ticker)

tickers = [s.replace('\n', '') for s in tickers]
start = datetime(2000,1,1)
end = datetime(2022,1,1)
data = yf.download(tickers, start=start, end=end)

data.index = pd.to_datetime(data.index)
data = data.sort_index()
SP_Close = data['Adj Close']
SP_Close=SP_Close.dropna(axis=0, how='all')
SP_Close=SP_Close.dropna(axis=1)
pd.set_option('display.max_rows', 20 )
SP_Close
"""
# Out:
# "\nresp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')\nsoup = bs.BeautifulSoup(resp.text, 'lxml')\ntable = soup.find('table', {'class': 'wikitable sortable'})\ntickers = []\nfor row in table.findAll('tr')[1:]:\n    ticker = row.findAll('td')[0].text\n    tickers.append(ticker)\n\ntickers = [s.replace('\n', '') for s in tickers]\nstart = datetime(2000,1,1)\nend = datetime(2022,1,1)\ndata = yf.download(tickers, start=start, end=end)\n\ndata.index = pd.to_datetime(data.index)\ndata = data.sort_index()\nSP_Close = data['Adj Close']\nSP_Close=SP_Close.dropna(axis=0, how='all')\nSP_Close=SP_Close.dropna(axis=1)\npd.set_option('display.max_rows', 20 )\nSP_Close\n"

# %%
#read in stock data from pi
SP_Close = pd.read_pickle('SP_Close.pkl')
SP_train = SP_Close[:'2018-01-01']
SP_test =  SP_Close['2018-01-01':]

# %%
SP_train.head()
# Out:
#                     A      AAPL       ABC      ABMD       ABT       ADBE  \
# Date
# 2000-01-03  44.221344  0.854541  3.025873  18.25000  9.347846  16.274675
# 2000-01-04  40.843311  0.782494  2.819287  17.81250  9.080765  14.909398
# 2000-01-05  38.309803  0.793945  3.038025  18.00000  9.064073  15.204173
# 2000-01-06  36.851112  0.725238  3.268915  18.03125  9.381230  15.328291
# 2000-01-07  39.922039  0.759592  3.694239  17.93750  9.481387  16.072985
#
#                   ADI       ADM        ADP      ADSK  ...        WMT  \
# Date                                                  ...
# 2000-01-03  29.523603  6.713816  25.847561  8.052906  ...  44.580296
# 2000-01-04  28.030031  6.643880  25.847561  7.660817  ...  42.912186
# 2000-01-05  28.439224  6.538982  25.599024  7.178244  ...  42.036430
# 2000-01-06  27.661741  6.573946  25.940754  6.740914  ...  42.495152
# 2000-01-07  28.439224  6.678852  26.531029  7.540174  ...  45.706272
#
#                  WRB       WST         WY       XEL        XOM      XRAY  \
# Date
# 2000-01-03  1.278264  5.451855  12.421493  7.445602  19.671473  6.852272
# 2000-01-04  1.238933  5.508176  11.954857  7.617051  19.294680  6.852272
# 2000-01-05  1.219267  5.485648  12.588147  7.910958  20.346552  6.970727
# 2000-01-06  1.290063  5.429327  13.177001  7.837479  21.398418  6.979842
# 2000-01-07  1.270398  5.485648  12.743696  7.837479  21.335625  6.961617
#
#                  YUM       ZBRA       ZION
# Date
# 2000-01-03  4.861766  25.027779  38.801506
# 2000-01-04  4.764044  24.666668  36.922596
# 2000-01-05  4.788472  25.138889  36.878899
# 2000-01-06  4.747756  23.777779  37.403233
# 2000-01-07  4.641887  23.513889  37.490639
#
# [5 rows x 367 columns]

# %%
SP_train.tail()
# Out:
#                     A       AAPL        ABC        ABMD        ABT  \
# Date
# 2017-12-22  65.034782  41.731140  86.004715  191.639999  52.917374
# 2017-12-26  64.938217  40.672424  86.739548  189.539993  52.982433
# 2017-12-27  64.986504  40.679585  86.134933  190.419998  53.419315
# 2017-12-28  65.131348  40.794033  86.125641  190.550003  53.410019
# 2017-12-29  64.811005  40.352901  85.409393  187.410004  53.047497
#
#                   ADBE        ADI        ADM         ADP        ADSK  ...  \
# Date                                                                  ...
# 2017-12-22  175.000000  81.833565  35.416145  106.914101  103.889999  ...
# 2017-12-26  174.440002  81.630928  35.477833  107.545258  103.800003  ...
# 2017-12-27  175.360001  82.063828  35.460205  107.261719  104.580002  ...
# 2017-12-28  175.550003  82.321709  35.486645  107.307449  105.070000  ...
# 2017-12-29  175.240005  81.999352  35.319210  107.197662  104.830002  ...
#
#                   WMT        WRB        WST         WY        XEL        XOM  \
# Date
# 2017-12-22  90.357903  28.866503  97.872253  29.092234  42.437065  66.389351
# 2017-12-26  91.231949  28.866503  97.528107  29.192152  42.067673  66.397224
# 2017-12-27  91.323959  28.931648  97.724762  29.225464  42.360115  66.333992
# 2017-12-28  91.452782  29.220720  97.360954  29.358677  42.608257  66.428864
# 2017-12-29  90.854729  29.171869  97.016815  29.358677  42.634838  66.128418
#
#                  XRAY        YUM        ZBRA       ZION
# Date
# 2017-12-22  63.499165  76.503891  105.150002  45.769455
# 2017-12-26  63.923660  76.308914  104.790001  45.350365
# 2017-12-27  63.701767  76.503891  104.949997  45.216610
# 2017-12-28  64.173187  76.754570  104.279999  45.778381
# 2017-12-29  63.593575  75.770409  103.800003  45.323620
#
# [5 rows x 367 columns]

# %%
SP_test.tail()
# Out:
#                      A        AAPL         ABC        ABMD         ABT  \
# Date
# 2021-12-27  158.282700  179.836319  131.471329  357.829987  140.403183
# 2021-12-28  158.721420  178.799164  131.929840  357.440002  139.420593
# 2021-12-29  160.187180  178.888916  132.906647  361.839996  140.135193
# 2021-12-30  160.416534  177.712143  133.335266  362.059998  139.946625
# 2021-12-31  159.190079  177.083878  132.458115  359.170013  139.688568
#
#                   ADBE         ADI        ADM         ADP        ADSK  ...  \
# Date                                                                   ...
# 2021-12-27  577.679993  174.617828  65.720932  245.068527  284.299988  ...
# 2021-12-28  569.359985  173.533127  66.576385  244.849625  282.769989  ...
# 2021-12-29  569.289978  174.667587  66.655968  246.779999  282.570007  ...
# 2021-12-30  570.530029  173.931168  66.506760  244.342148  281.709991  ...
# 2021-12-31  567.059998  174.916367  67.232895  245.357101  281.190002  ...
#
#                    WMT        WRB         WST         WY        XEL  \
# Date
# 2021-12-27  139.709854  54.160683  465.444122  38.111694  66.356621
# 2021-12-28  141.714783  54.566757  464.425049  38.303886  67.151077
# 2021-12-29  141.645309  54.932884  467.542084  39.091873  67.488716
# 2021-12-30  142.101868  54.273849  470.888885  39.370552  67.756844
# 2021-12-31  143.610519  54.846344  468.561127  39.572353  67.230515
#
#                   XOM       XRAY         YUM        ZBRA       ZION
# Date
# 2021-12-27  61.211414  55.700321  137.372253  606.330017  62.687782
# 2021-12-28  61.013607  55.779961  137.342392  597.320007  62.787273
# 2021-12-29  60.479530  56.397194  138.019257  601.119995  63.125534
# 2021-12-30  60.123474  56.058052  137.750504  597.539978  62.807171
# 2021-12-31  60.519089  55.649090  138.218338  595.200012  62.837017
#
# [5 rows x 367 columns]

# %% [markdown]
# ## Testing Initial Portfolio without Bayes

# %%
five_year_data=SP_Close[:1265] #5 years of data
five_year_data.tail()
# Out:
#                     A      AAPL        ABC   ABMD        ABT       ADBE  \
# Date
# 2005-01-07  13.948145  1.057321  11.317923  14.29  15.050692  29.384233
# 2005-01-10  13.880588  1.052894  11.317923  14.42  15.196447  29.404230
# 2005-01-11  13.641056  0.985713  11.345287  14.31  14.917611  29.054298
# 2005-01-12  13.622632  0.999455  11.349197  14.17  14.952654  29.484215
# 2005-01-13  13.333963  1.065719  11.161545  12.45  14.665908  29.104290
#
#                   ADI        ADM        ADP       ADSK  ...        WMT  \
# Date                                                    ...
# 2005-01-07  23.419283  14.685472  22.294916  34.282318  ...  37.189400
# 2005-01-10  23.327053  14.806506  22.310617  34.222351  ...  37.003414
# 2005-01-11  23.109659  14.598061  22.352486  32.373302  ...  36.913879
# 2005-01-12  23.425869  14.503919  22.148371  31.953520  ...  37.251415
# 2005-01-13  23.122826  14.692193  21.719221  31.763618  ...  36.948326
#
#                  WRB        WST         WY       XEL        XOM       XRAY  \
# Date
# 2005-01-07  6.975882  10.584788  13.893993  9.064570  28.189127  24.471771
# 2005-01-10  7.007394  10.730645  13.951578  9.189453  28.296703  25.020788
# 2005-01-11  7.011895  10.605624  13.819960  9.220676  28.223104  25.020788
# 2005-01-12  7.058410  10.684803  13.782939  9.210265  28.642065  24.935287
# 2005-01-13  7.074916  10.605624  13.686286  9.298729  28.619408  24.669779
#
#                   YUM       ZBRA       ZION
# Date
# 2005-01-07  12.140292  53.099998  49.812916
# 2005-01-10  12.142917  53.840000  49.843578
# 2005-01-11  12.182205  51.669998  49.874241
# 2005-01-12  12.085085  50.910000  49.406685
# 2005-01-13  11.911839  51.060001  48.831833
#
# [5 rows x 367 columns]

# %%
mu = mean_historical_return(five_year_data)
S = CovarianceShrinkage(five_year_data).ledoit_wolf()
ef = EfficientFrontier(mu, S)
weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()
#ef.save_weights_to_file("weights.txt")  # saves to file
print(ef.portfolio_performance(verbose=True))
# Out:
# Expected annual return: 44.8%
# Annual volatility: 13.6%
# Sharpe Ratio: 3.15
# (0.44813889416852737, 0.13591570334791886, 3.1500325835975818)

# %% [markdown]
# ## Look at some correlations and clustering to gather ideas

# %%
corr = five_year_data.corr()
plt.figure(figsize=(12,8))
sns.clustermap(corr)

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(corr, method='ward'))
plt.axhline(y=6, color='r', linestyle='--')

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=None, affinity='euclidean', linkage='ward',distance_threshold=4)  
kclusters = cluster.fit_predict(corr)
stock_clusters=pd.DataFrame(SP_Close.columns.values)
stock_clusters=stock_clusters.set_index(0)
stock_clusters['cluster']=kclusters
print(stock_clusters['cluster'].max())
# Out:
# 64

# %%
#plt.hist(stock_clusters,bins=stock_clusters['cluster'].max())

# %%
#shrinkage
def calculate_posterior_mean(prior_pop, like_pop): #for returns use geo mean then multiply by 252 to annualize at end
    w0 = prior_pop.std()
    mu0 = prior_pop.mean() - w0**2/2
    w = like_pop.std()
    dbar = like_pop.mean() - w**2/2

    B = w**2/(w**2+w0**2)
    mu_s =dbar+B*(mu0-dbar)
    return mu_s * 252

# %% [markdown]
# ## Markowitz Rebalancer

# %%
def Markowits_Bayes_Rebalance(securities_vector, rebalance_period,prior_period,update_period=0,verbose=True,weight_bounds=(-.01,.1)):
    #Bayesian update not yet implemented
    i=1
    i_ =round((len(securities_vector)-prior_period)/rebalance_period)
    weights_list=[]
    dates=[]
    for p in range(0,len(securities_vector)-prior_period,rebalance_period):
        
        prior_vector = securities_vector[p:prior_period+p]
        
        if verbose:
            print("Iteration " + str(i) + " of " + str(i_))
            print(str(prior_vector.index[0]) + " - " + str(prior_vector.index[-1]))
            
            
        mu = mean_historical_return(prior_vector)
        S = CovarianceShrinkage(prior_vector).ledoit_wolf()
        ef = EfficientFrontier(mu, S,weight_bounds=weight_bounds)
        weights = ef.max_sharpe()
        cleaned_weights = ef.clean_weights()
        weights_list.append(cleaned_weights)
        dates.append(prior_vector.index[-1])
        i+=1
    weight_df=pd.DataFrame(weights_list)
    weight_df.index=dates

    return weight_df

# %%
#THIS NEEDS TO BE FIXED - ASSUMES PORTFOLIO IS SET BACK TO LAST REBLANCE WEIGHT AT MARKET CLOSE EVERY DAY
# NEED TO FIGURE OUT HOW TO CONVERT THE ORIGINAL weight SERIES TO A PROPER DAILYw eightSERIES WITH RESPECT TO THE LAST REBALANCE WEIGHTS

def Portfolio_backtest(weight_vector,securities_vector=SP_train) :
    weight_vector_n = weight_vector
    weight_vector_n = weight_vector.reindex(weight_vector.index.union(securities_vector.index)).ffill()
    weight_vector_n = weight_vector_n[weight_vector.index[0]:]
    return_frame = np.exp(np.log(securities_vector).diff())-1
    weighted_returns=weight_vector_n.shift(1)*return_frame
    port_returns = np.sum(weighted_returns, axis=1) #shift so that we are using the weights we had over that period rather than the ones we found with hindsight
    port_returns = port_returns[weight_vector.index[0]:]
    total_return=(port_returns+1).cumprod()
    total_return.plot()
    reports.metrics(port_returns,mode='basic')
    plt.title('Cumulative Return')

# %%
# Evan's code, with forward-fill removed

securities_vector=SP_train
weight_vector = monthly_vanilla_markowitz
weight_vector_n = weight_vector
weight_vector_n = weight_vector.reindex(weight_vector.index.union(securities_vector.index))
weight_vector_n = weight_vector_n[weight_vector.index[0]:]
return_frame = np.exp(np.log(securities_vector).diff())-1
weighted_returns=weight_vector_n.shift(1)*return_frame
port_returns = np.sum(weighted_returns, axis=1) #shift so that we are using the weights we had over that period rather than the ones we found with hindsight
port_returns = port_returns[weight_vector.index[0]:]
total_return=(port_returns+1).cumprod()
total_return.plot()
reports.metrics(port_returns,mode='basic')
plt.title('Cumulative Return')
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      2.0%
#
# Cumulative Return   7.42%
# CAGR﹪              0.51%
#
# Sharpe              0.25
# Prob. Sharpe Ratio  83.87%
# Sortino             0.32
# Sortino/√2          0.23
# Omega               1.42
#
# Max Drawdown        -9.94%
# Longest DD Days     2011
#
# Gain/Pain Ratio     0.42
# Gain/Pain (1M)      0.42
#
# Payoff Ratio        0.73
# Profit Factor       1.42
# Common Sense Ratio  -
# CPC Index           0.69
# Tail Ratio          -
# Outlier Win Ratio   3.66
# Outlier Loss Ratio  -0.0
#
# MTD                 0.0%
# 3M                  -0.48%
# 6M                  -0.28%
# YTD                 0.01%
# 1Y                  0.01%
# 3Y (ann.)           -0.36%
# 5Y (ann.)           0.92%
# 10Y (ann.)          0.21%
# All-time (ann.)     0.51%
#
# Avg. Drawdown       -2.21%
# Avg. Drawdown Days  506
# Recovery Factor     0.75
# Ulcer Index         0.04
# Serenity Index      0.04
# Text(0.5, 1.0, 'Cumulative Return')

# %%
# Tainon's code, with forward-fill removed and calculating daily returns

securities_vector=SP_train
weight_vector = monthly_vanilla_markowitz

weight_vector_n = weight_vector
ret_dates = weight_vector_n.index
weight_vector_n = weight_vector.reindex(weight_vector.index.union(securities_vector.index))#.ffill()
weight_vector_n = weight_vector_n[weight_vector.index[0]:]
return_frame = np.exp(np.log(securities_vector).diff())-1
weighted_returns=weight_vector_n.shift(1)*return_frame
port_returns = np.sum(weighted_returns, axis=1) #shift so that we are using the weights we had over that period rather than the ones we found with hindsight
port_returns = port_returns[weight_vector.index[0]:]+1
ret_ind = []
for i in ret_dates:
    ret_ind.append(port_returns.index.get_loc(i)+1)
ret_ind.append(len(port_returns)-1)
print(ret_ind)
for i in range(len(ret_ind)-1):
    numdays = ret_ind[i+1]-ret_ind[i]
    day_val = (port_returns.iat[ret_ind[i]])**(1/numdays)
#     print(numdays,day_val)
    for j in range(ret_ind[i],ret_ind[i+1]):
#         print(port_returns.iat[j])
        port_returns.iat[j] = day_val
total_return=(port_returns).cumprod()
total_return.plot()
reports.metrics(port_returns,mode='basic')
plt.title('Cumulative Return')
# Out:
# [1, 64, 127, 190, 253, 316, 379, 442, 505, 568, 631, 694, 757, 820, 883, 946, 1009, 1072, 1135, 1198, 1261, 1324, 1387, 1450, 1513, 1576, 1639, 1702, 1765, 1828, 1891, 1954, 2017, 2080, 2143, 2206, 2269, 2332, 2395, 2458, 2521, 2584, 2647, 2710, 2773, 2836, 2899, 2962, 3025, 3088, 3151, 3214, 3277, 3340, 3403, 3466, 3516]
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      2.0%
#
# Cumulative Return   -0.0%
# CAGR﹪              0.0%
#
# Sharpe              0.0
# Prob. Sharpe Ratio  50.03%
# Sortino             0.0
# Sortino/√2          0.0
# Omega               1.0
#
# Max Drawdown        -0.08%
# Longest DD Days     3178
#
# Gain/Pain Ratio     0.0
# Gain/Pain (1M)      0.0
#
# Payoff Ratio        1.11
# Profit Factor       1.0
# Common Sense Ratio  -
# CPC Index           0.53
# Tail Ratio          -
# Outlier Win Ratio   0.0
# Outlier Loss Ratio  -0.0
#
# MTD                 0.01%
# 3M                  -0.0%
# 6M                  0.0%
# YTD                 -0.01%
# 1Y                  -0.01%
# 3Y (ann.)           -0.0%
# 5Y (ann.)           -0.0%
# 10Y (ann.)          -0.0%
# All-time (ann.)     0.0%
#
# Avg. Drawdown       -0.07%
# Avg. Drawdown Days  2366
# Recovery Factor     -0.0
# Ulcer Index         0.0
# Serenity Index      -0.0
# Text(0.5, 1.0, 'Cumulative Return')

# %%
monthly_vanilla_markowitz = Markowits_Bayes_Rebalance(SP_train,63,253*4,weight_bounds=(-.002,.2),verbose=False)

# %%
Portfolio_backtest(monthly_vanilla_markowitz)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   682.74%
# CAGR﹪              15.87%
#
# Sharpe              0.94
# Prob. Sharpe Ratio  99.97%
# Sortino             1.37
# Sortino/√2          0.97
# Omega               1.18
#
# Max Drawdown        -52.12%
# Longest DD Days     1342
#
# Gain/Pain Ratio     0.18
# Gain/Pain (1M)      1.24
#
# Payoff Ratio        0.97
# Profit Factor       1.18
# Common Sense Ratio  1.16
# CPC Index           0.63
# Tail Ratio          0.98
# Outlier Win Ratio   3.33
# Outlier Loss Ratio  3.63
#
# MTD                 -1.77%
# 3M                  11.08%
# 6M                  16.65%
# YTD                 41.57%
# 1Y                  41.21%
# 3Y (ann.)           16.54%
# 5Y (ann.)           20.53%
# 10Y (ann.)          10.76%
# All-time (ann.)     15.87%
#
# Avg. Drawdown       -2.36%
# Avg. Drawdown Days  27
# Recovery Factor     13.1
# Ulcer Index         0.18
# Serenity Index      1.18

# %% [markdown]
# ## Implement Clustering Influenced Dynamic Constraints

# %%
def Cluster_Constraints(clusters,u_coef,l_coef): # weight coef for how overweight you can go
    cluster_list = set(clusters.cluster)
    cluster_map = dict(zip(clusters.index,clusters.cluster))
    cluster_totals=[clusters.value_counts()[x] for x in cluster_list]
    cluster_pct=np.array(cluster_totals)/len(clusters)
    cluster_upper_l = dict(zip(cluster_list, cluster_pct*u_coef))
    cluster_lower_l = dict(zip(cluster_list, - l_coef*cluster_pct))
    return cluster_map, cluster_upper_l, cluster_lower_l

# %%
#for testing preset clusters
def get_clusters(corr, cluster_number = 45, Thresh = None):
    if Thresh == None:
        cluster = AgglomerativeClustering(n_clusters=cluster_number, affinity='euclidean', linkage='ward')
    else:
        cluster = AgglomerativeClustering(n_clusters=None, affinity='euclidean', linkage='ward',distance_threshold=Thresh) 
    kclusters = cluster.fit_predict(corr)
    stock_clusters=pd.DataFrame(SP_Close.columns.values)
    stock_clusters=stock_clusters.set_index(0)
    stock_clusters['cluster']=kclusters
    return stock_clusters

# %%
class constrained_clusterings_precomputed:
    
    def __init__(self,lookback):
        llist = [1,2,3,4,5]
        if (int(lookback) != lookback) or (int(lookback) not in llist):
            raise ValueError("Only lookback periods of",llist,"supported")
            
        self.df = pd.read_pickle(str(int(lookback))+'.pkl')
        self.names_df = pd.read_pickle('names.pkl')
        
#         corr_threshold = 0.7
#         pct_threshold = 0.1
#         date = datetime.strptime('3-31-2030','%m-%d-%Y')
        
            
    def calcthresholds(self,corr_threshold,pct_threshold,date,DEBUG=False):
        if date < min(self.df.index):
            raise ValueError("Date must be >=",min(self.df.index))
        if date > max(self.df.index):
            print("WARNING: USING",max(self.df.index),"FOR INPUT DATE",date)
        inddate = max(self.df.index[self.df.index <= date])
#         print(inddate)
#         print(self.df.loc[inddate])
        if DEBUG:
            print("DEBUG: USING",inddate,"FOR INPUT DATE",date)
        
        clusters = self.df.loc[inddate]['Clusters']
        numstocks = self.df.loc[inddate]['Numstocks']
        internals = self.df.loc[inddate]['Corrs']
        sz = clusters.shape[0]
        
        tmp = np.sum((internals<corr_threshold)*(numstocks/sz),axis=1)<pct_threshold
        ret = (np.arange(0,sz)+1)[tmp]
        if ret.shape[0] <= 0:
            return None
        OPTIMAL_NUMBER_OF_CLUSTERS = ret[0]
        if DEBUG:
            print("DEBUG: OPTIMAL NUMBER OF CLUSTERS:",OPTIMAL_NUMBER_OF_CLUSTERS)
        
        ret_df = self.names_df
        ret_df = ret_df.set_index(0)
        ret_df['cluster'] = clusters[OPTIMAL_NUMBER_OF_CLUSTERS-1,:].astype(int)
        
#         print(OPTIMAL_NUMBER_OF_CLUSTERS)
#         print(ret_df)
        return ret_df

# %%
import os
filelist = ['1.pkl','2.pkl','3.pkl','4.pkl','5.pkl','names.pkl']
for file in filelist:
    if not os.path.exists(file):
        raise ValueError("All of",filelist,"must be present")
        
look1 = constrained_clusterings_precomputed(1)
look2 = constrained_clusterings_precomputed(2)
look3 = constrained_clusterings_precomputed(3)
look4 = constrained_clusterings_precomputed(4)
look5 = constrained_clusterings_precomputed(5)

# %%
def get_clusters_precomputed(lookback,corr_threshold,pct_threshold,date,DEBUG=False):
    llist = [1,2,3,4,5]
    if (int(lookback) != lookback) or (int(lookback) not in llist):
        raise ValueError("Only lookback periods of",llist,"supported")
        
    # Apparently pattern matching wasn't implemented until Python 3.10
    if lookback == 1:
        return look1.calcthresholds(corr_threshold,pct_threshold,date,DEBUG)
    elif lookback == 2:
        return look2.calcthresholds(corr_threshold,pct_threshold,date,DEBUG)
    elif lookback == 3:
        return look3.calcthresholds(corr_threshold,pct_threshold,date,DEBUG)
    elif lookback == 4:
        return look4.calcthresholds(corr_threshold,pct_threshold,date,DEBUG)
    elif lookback == 5:
        return look5.calcthresholds(corr_threshold,pct_threshold,date,DEBUG)
    else:
        raise ValueError("Something went wrong")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def Markowits_Bayes_Cluster_Rebalance(securities_vector, rebalance_period=21,prior_period = 253*5, update_period=0,
                                      verbose=False,weight_bounds=(-.005,.15), cluster_u_coef=2, cluster_l_coef=-.05,
                                      corr_thresh = .75,leave_out_pct = .05, clust_num = None, reverse_prior=False):
    z=1
    i_ =round((len(securities_vector)-prior_period)/rebalance_period)
    weights_list=[]
    dates=[]
    cluster_list=[]
    num=clust_num
    for p in range(0,len(securities_vector)-prior_period,rebalance_period):
        
        prior_vector = securities_vector[p:prior_period+p]
        update_vector = securities_vector[prior_period+p-update_period:prior_period+p]
        if verbose:
            print("Iteration " + str(z) + " of " + str(i_))
            print(str(prior_vector.index[0]) + " - " + str(prior_vector.index[-1]))
            
        
        if clust_num == None:
            clusters= get_clusters_precomputed(prior_period/253,corr_thresh, leave_out_pct, date=prior_vector.index[-1])
            num = clusters.max().values[0]
            cluster_list.append(max(clusters))    
        else:
            clusters = get_clusters(prior_vector.corr(), cluster_number = clust_num)
            cluster_list.append(clust_num) 
        c_map, c_upper, c_lower = Cluster_Constraints(clusters,cluster_u_coef,cluster_l_coef)
        mu = mean_historical_return(prior_vector)  
        if update_period != 0:
            if reverse_prior:
                for i in range(num):
                    stocksNcluster = clusters.loc[clusters['cluster']==i].index
                    for stock in stocksNcluster:
                        mu.loc[stock] = calculate_posterior_mean(prior_vector[stock].pct_change().dropna().to_numpy(),
                                                                 update_vector[stocksNcluster].pct_change().dropna().to_numpy())
            else:
                for i in range(num):
                    stocksNcluster = clusters.loc[clusters['cluster']==i].index
                    for stock in stocksNcluster:
                        mu.loc[stock] = calculate_posterior_mean(prior_vector[stocksNcluster].pct_change().dropna().to_numpy(),
                                                                 update_vector[stock].pct_change().dropna().to_numpy())
            
        S = CovarianceShrinkage(prior_vector).ledoit_wolf()
        ef = EfficientFrontier(mu, S,weight_bounds=weight_bounds)
        if cluster_u_coef<100 and cluster_l_coef>-100: ef.add_sector_constraints(c_map, c_lower, c_upper)
        weights = ef.max_sharpe()
        cleaned_weights = ef.clean_weights()
        weights_list.append(cleaned_weights)
        dates.append(prior_vector.index[-1])
        z+=1
    cluster_ts=pd.DataFrame(cluster_list)
    cluster_ts.index=dates
    cluster_ts.columns = ['Clusters']
    weight_df=pd.DataFrame(weights_list)
    weight_df.index=dates

    return weight_df, cluster_ts

# %% [markdown]
# ## Shrinkage without cluster constraints

# %%
returns_shrinkage, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*4,21*3, weight_bounds=(-.002,.2), cluster_u_coef=1000, cluster_l_coef=-1000,clust_num=50,verbose=False)

# %%
Portfolio_backtest(returns_shrinkage,SP_train)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   285.13%
# CAGR﹪              10.13%
#
# Sharpe              0.72
# Prob. Sharpe Ratio  99.65%
# Sortino             1.03
# Sortino/√2          0.73
# Omega               1.13
#
# Max Drawdown        -44.36%
# Longest DD Days     1637
#
# Gain/Pain Ratio     0.13
# Gain/Pain (1M)      0.8
#
# Payoff Ratio        0.96
# Profit Factor       1.13
# Common Sense Ratio  1.1
# CPC Index           0.59
# Tail Ratio          0.97
# Outlier Win Ratio   3.32
# Outlier Loss Ratio  3.58
#
# MTD                 0.38%
# 3M                  12.37%
# 6M                  14.38%
# YTD                 25.67%
# 1Y                  24.84%
# 3Y (ann.)           12.81%
# 5Y (ann.)           16.52%
# 10Y (ann.)          8.78%
# All-time (ann.)     10.13%
#
# Avg. Drawdown       -2.53%
# Avg. Drawdown Days  33
# Recovery Factor     6.43
# Ulcer Index         0.15
# Serenity Index      0.63

# %% [markdown]
# ## Shrinkage with stock as prior and cluster as likelihood

# %%
returns_shrinkage, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*4,21*3, weight_bounds=(-.002,.2), cluster_u_coef=1000, cluster_l_coef=-1000,clust_num=50,verbose=False, reverse_prior=True)

# %%
Portfolio_backtest(returns_shrinkage)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   575.41%
# CAGR﹪              14.65%
#
# Sharpe              1.01
# Prob. Sharpe Ratio  99.99%
# Sortino             1.44
# Sortino/√2          1.02
# Omega               1.19
#
# Max Drawdown        -44.8%
# Longest DD Days     1231
#
# Gain/Pain Ratio     0.19
# Gain/Pain (1M)      1.25
#
# Payoff Ratio        0.95
# Profit Factor       1.19
# Common Sense Ratio  1.15
# CPC Index           0.63
# Tail Ratio          0.96
# Outlier Win Ratio   3.19
# Outlier Loss Ratio  3.48
#
# MTD                 0.49%
# 3M                  13.43%
# 6M                  13.46%
# YTD                 27.74%
# 1Y                  27.28%
# 3Y (ann.)           11.55%
# 5Y (ann.)           14.8%
# 10Y (ann.)          10.99%
# All-time (ann.)     14.65%
#
# Avg. Drawdown       -2.16%
# Avg. Drawdown Days  27
# Recovery Factor     12.84
# Ulcer Index         0.13
# Serenity Index      1.55

# %% [markdown]
# ## Shrinkage and dynamic clusters

# %%
returns_shrinkage_dy, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*4,21*3, weight_bounds=(-.002,.2), cluster_u_coef=1000, cluster_l_coef=-1000,verbose=False)

# %%
Portfolio_backtest(returns_shrinkage_dy)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   262.14%
# CAGR﹪              9.65%
#
# Sharpe              0.69
# Prob. Sharpe Ratio  99.51%
# Sortino             0.99
# Sortino/√2          0.7
# Omega               1.13
#
# Max Drawdown        -45.23%
# Longest DD Days     1655
#
# Gain/Pain Ratio     0.13
# Gain/Pain (1M)      0.73
#
# Payoff Ratio        0.94
# Profit Factor       1.13
# Common Sense Ratio  1.08
# CPC Index           0.58
# Tail Ratio          0.96
# Outlier Win Ratio   3.35
# Outlier Loss Ratio  3.61
#
# MTD                 0.34%
# 3M                  12.41%
# 6M                  14.35%
# YTD                 27.62%
# 1Y                  26.76%
# 3Y (ann.)           12.26%
# 5Y (ann.)           16.51%
# 10Y (ann.)          8.35%
# All-time (ann.)     9.65%
#
# Avg. Drawdown       -2.62%
# Avg. Drawdown Days  36
# Recovery Factor     5.8
# Ulcer Index         0.16
# Serenity Index      0.52

# %% [markdown]
# ## With static Cluster Constraints no shrinkage

# %%
returns_static, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*4, weight_bounds=(-.002,.2), cluster_u_coef=3, cluster_l_coef=-.05,clust_num=50,verbose=False)

# %%
Portfolio_backtest(returns_static)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   703.53%
# CAGR﹪              16.09%
#
# Sharpe              0.98
# Prob. Sharpe Ratio  99.98%
# Sortino             1.42
# Sortino/√2          1.01
# Omega               1.19
#
# Max Drawdown        -48.81%
# Longest DD Days     1287
#
# Gain/Pain Ratio     0.19
# Gain/Pain (1M)      1.39
#
# Payoff Ratio        0.94
# Profit Factor       1.19
# Common Sense Ratio  1.19
# CPC Index           0.63
# Tail Ratio          1.0
# Outlier Win Ratio   3.57
# Outlier Loss Ratio  3.62
#
# MTD                 -1.22%
# 3M                  10.67%
# 6M                  16.34%
# YTD                 36.75%
# 1Y                  36.49%
# 3Y (ann.)           15.69%
# 5Y (ann.)           20.89%
# 10Y (ann.)          11.53%
# All-time (ann.)     16.09%
#
# Avg. Drawdown       -2.25%
# Avg. Drawdown Days  25
# Recovery Factor     14.41
# Ulcer Index         0.14
# Serenity Index      1.84

# %% [markdown]
# ## dynamic cluster constraints no shrinkage

# %%
returns_dynamic, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*4, weight_bounds=(-.002,.2), cluster_u_coef=3, cluster_l_coef=-.05,verbose=False)

# %%
Portfolio_backtest(returns_dynamic)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   641.54%
# CAGR﹪              15.42%
#
# Sharpe              0.95
# Prob. Sharpe Ratio  99.98%
# Sortino             1.37
# Sortino/√2          0.97
# Omega               1.18
#
# Max Drawdown        -50.37%
# Longest DD Days     1519
#
# Gain/Pain Ratio     0.18
# Gain/Pain (1M)      1.28
#
# Payoff Ratio        0.95
# Profit Factor       1.18
# Common Sense Ratio  1.16
# CPC Index           0.62
# Tail Ratio          0.98
# Outlier Win Ratio   3.54
# Outlier Loss Ratio  3.52
#
# MTD                 -1.18%
# 3M                  12.07%
# 6M                  18.34%
# YTD                 38.72%
# 1Y                  38.39%
# 3Y (ann.)           15.66%
# 5Y (ann.)           20.91%
# 10Y (ann.)          11.07%
# All-time (ann.)     15.42%
#
# Avg. Drawdown       -2.29%
# Avg. Drawdown Days  26
# Recovery Factor     12.74
# Ulcer Index         0.16
# Serenity Index      1.36

# %% [markdown]
# ## Use Shrinkage and Cluster constraints

# %%
returns_s, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*4,21*3, weight_bounds=(-.002,.2), cluster_u_coef=3, cluster_l_coef=-.05,verbose=False)

# %%
Portfolio_backtest(returns_s)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   281.1%
# CAGR﹪              10.05%
#
# Sharpe              0.73
# Prob. Sharpe Ratio  99.66%
# Sortino             1.04
# Sortino/√2          0.73
# Omega               1.14
#
# Max Drawdown        -41.56%
# Longest DD Days     1868
#
# Gain/Pain Ratio     0.14
# Gain/Pain (1M)      0.92
#
# Payoff Ratio        0.94
# Profit Factor       1.14
# Common Sense Ratio  1.07
# CPC Index           0.58
# Tail Ratio          0.95
# Outlier Win Ratio   3.4
# Outlier Loss Ratio  3.61
#
# MTD                 0.38%
# 3M                  13.4%
# 6M                  14.21%
# YTD                 25.79%
# 1Y                  25.18%
# 3Y (ann.)           13.22%
# 5Y (ann.)           17.99%
# 10Y (ann.)          9.49%
# All-time (ann.)     10.05%
#
# Avg. Drawdown       -2.21%
# Avg. Drawdown Days  33
# Recovery Factor     6.76
# Ulcer Index         0.14
# Serenity Index      0.74

# %% [markdown]
# ## Shrinkage and Cluster Constraints Stock as Prior

# %%
returns_shrink_dyn_rev, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*4,21*3, weight_bounds=(-.002,.2), cluster_u_coef=3, cluster_l_coef=-.05,verbose=False,reverse_prior=True)

# %%
Portfolio_backtest(returns_shrink_dyn_rev)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2004-01-13
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   754.16%
# CAGR﹪              16.6%
#
# Sharpe              1.21
# Prob. Sharpe Ratio  100.0%
# Sortino             1.76
# Sortino/√2          1.24
# Omega               1.24
#
# Max Drawdown        -35.27%
# Longest DD Days     1043
#
# Gain/Pain Ratio     0.24
# Gain/Pain (1M)      2.22
#
# Payoff Ratio        0.97
# Profit Factor       1.24
# Common Sense Ratio  1.25
# CPC Index           0.67
# Tail Ratio          1.01
# Outlier Win Ratio   3.38
# Outlier Loss Ratio  3.54
#
# MTD                 -0.48%
# 3M                  11.85%
# 6M                  13.76%
# YTD                 24.84%
# 1Y                  24.78%
# 3Y (ann.)           15.6%
# 5Y (ann.)           21.0%
# 10Y (ann.)          13.78%
# All-time (ann.)     16.6%
#
# Avg. Drawdown       -1.6%
# Avg. Drawdown Days  18
# Recovery Factor     21.38
# Ulcer Index         0.09
# Serenity Index      4.03

# %% [markdown]
# ## Using optimal hyperparameters

# %% [markdown]
# ### cluster as prior 3 month update

# %%
returns_opt_3, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*2,21*3,corr_thresh=.8, weight_bounds=(-.003,.02), cluster_u_coef=3, cluster_l_coef=-.02,verbose=False)

# %%
Portfolio_backtest(returns_opt_3)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2002-01-09
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   387.72%
# CAGR﹪              10.42%
#
# Sharpe              0.76
# Prob. Sharpe Ratio  99.89%
# Sortino             1.07
# Sortino/√2          0.76
# Omega               1.15
#
# Max Drawdown        -47.96%
# Longest DD Days     1889
#
# Gain/Pain Ratio     0.15
# Gain/Pain (1M)      1.09
#
# Payoff Ratio        0.91
# Profit Factor       1.15
# Common Sense Ratio  1.05
# CPC Index           0.58
# Tail Ratio          0.92
# Outlier Win Ratio   3.6
# Outlier Loss Ratio  3.81
#
# MTD                 0.23%
# 3M                  9.74%
# 6M                  11.83%
# YTD                 25.74%
# 1Y                  24.98%
# 3Y (ann.)           15.06%
# 5Y (ann.)           17.02%
# 10Y (ann.)          8.09%
# All-time (ann.)     10.42%
#
# Avg. Drawdown       -1.82%
# Avg. Drawdown Days  27
# Recovery Factor     8.08
# Ulcer Index         0.15
# Serenity Index      0.77

# %% [markdown]
# ### stock as prior - These constrains had to be relaxed to make the problem feasible

# %%
returns_opt_3_rev, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*2,21*3,corr_thresh=.8, weight_bounds=(-.005,.07), cluster_u_coef=3, cluster_l_coef=-.08,reverse_prior=True)

# %%
Portfolio_backtest(returns_opt_3_rev)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2002-01-09
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   693.75%
# CAGR﹪              13.84%
#
# Sharpe              1.1
# Prob. Sharpe Ratio  100.0%
# Sortino             1.57
# Sortino/√2          1.11
# Omega               1.21
#
# Max Drawdown        -45.24%
# Longest DD Days     1454
#
# Gain/Pain Ratio     0.21
# Gain/Pain (1M)      1.6
#
# Payoff Ratio        0.98
# Profit Factor       1.21
# Common Sense Ratio  1.2
# CPC Index           0.66
# Tail Ratio          0.99
# Outlier Win Ratio   3.48
# Outlier Loss Ratio  3.93
#
# MTD                 0.71%
# 3M                  9.13%
# 6M                  11.32%
# YTD                 23.46%
# 1Y                  23.49%
# 3Y (ann.)           13.76%
# 5Y (ann.)           17.12%
# 10Y (ann.)          10.54%
# All-time (ann.)     13.84%
#
# Avg. Drawdown       -1.5%
# Avg. Drawdown Days  21
# Recovery Factor     15.33
# Ulcer Index         0.13
# Serenity Index      1.67

# %% [markdown]
# ### 1 year update

# %%
returns_opt_1, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*2,253,corr_thresh=.8, weight_bounds=(-.003,.05), cluster_u_coef=3, cluster_l_coef=-.05,verbose=False)

# %%
Portfolio_backtest(returns_opt_1)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2002-01-09
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   503.36%
# CAGR﹪              11.9%
#
# Sharpe              0.88
# Prob. Sharpe Ratio  99.98%
# Sortino             1.25
# Sortino/√2          0.88
# Omega               1.17
#
# Max Drawdown        -46.36%
# Longest DD Days     1472
#
# Gain/Pain Ratio     0.17
# Gain/Pain (1M)      1.25
#
# Payoff Ratio        0.92
# Profit Factor       1.17
# Common Sense Ratio  1.13
# CPC Index           0.61
# Tail Ratio          0.96
# Outlier Win Ratio   3.54
# Outlier Loss Ratio  3.71
#
# MTD                 -0.25%
# 3M                  8.84%
# 6M                  13.61%
# YTD                 30.52%
# 1Y                  30.33%
# 3Y (ann.)           12.92%
# 5Y (ann.)           16.54%
# 10Y (ann.)          9.1%
# All-time (ann.)     11.9%
#
# Avg. Drawdown       -1.73%
# Avg. Drawdown Days  25
# Recovery Factor     10.86
# Ulcer Index         0.14
# Serenity Index      1.16

# %% [markdown]
# ### stock as prior

# %%
returns_opt_1_rev, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*2,253,corr_thresh=.8, weight_bounds=(-.003,.03), cluster_u_coef=3, cluster_l_coef=-.02,verbose=False,reverse_prior=True)

# %%
Portfolio_backtest(returns_opt_1_rev)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2002-01-09
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   468.66%
# CAGR﹪              11.49%
#
# Sharpe              0.9
# Prob. Sharpe Ratio  99.98%
# Sortino             1.27
# Sortino/√2          0.9
# Omega               1.17
#
# Max Drawdown        -47.06%
# Longest DD Days     1583
#
# Gain/Pain Ratio     0.17
# Gain/Pain (1M)      1.3
#
# Payoff Ratio        0.92
# Profit Factor       1.17
# Common Sense Ratio  1.13
# CPC Index           0.61
# Tail Ratio          0.97
# Outlier Win Ratio   3.41
# Outlier Loss Ratio  3.7
#
# MTD                 0.64%
# 3M                  8.56%
# 6M                  12.11%
# YTD                 28.71%
# 1Y                  28.65%
# 3Y (ann.)           11.89%
# 5Y (ann.)           15.17%
# 10Y (ann.)          7.89%
# All-time (ann.)     11.49%
#
# Avg. Drawdown       -1.62%
# Avg. Drawdown Days  25
# Recovery Factor     9.96
# Ulcer Index         0.15
# Serenity Index      0.9

# %% [markdown]
# ### same length prior and likelihood

# %%
returns_opt_2y_rev, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*2,253*2,corr_thresh=.8, weight_bounds=(-.003,.03), cluster_u_coef=3, cluster_l_coef=-.03,reverse_prior=True)

# %%
Portfolio_backtest(returns_opt_2y_rev)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2002-01-09
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   514.41%
# CAGR﹪              12.03%
#
# Sharpe              0.94
# Prob. Sharpe Ratio  99.99%
# Sortino             1.34
# Sortino/√2          0.95
# Omega               1.18
#
# Max Drawdown        -45.31%
# Longest DD Days     1550
#
# Gain/Pain Ratio     0.18
# Gain/Pain (1M)      1.35
#
# Payoff Ratio        0.94
# Profit Factor       1.18
# Common Sense Ratio  1.14
# CPC Index           0.62
# Tail Ratio          0.97
# Outlier Win Ratio   3.37
# Outlier Loss Ratio  3.79
#
# MTD                 0.39%
# 3M                  9.3%
# 6M                  11.78%
# YTD                 28.16%
# 1Y                  28.03%
# 3Y (ann.)           11.64%
# 5Y (ann.)           15.24%
# 10Y (ann.)          8.74%
# All-time (ann.)     12.03%
#
# Avg. Drawdown       -1.61%
# Avg. Drawdown Days  24
# Recovery Factor     11.35
# Ulcer Index         0.14
# Serenity Index      1.13

# %% [markdown]
# ### sanity check - this should be the same result

# %%
returns_opt_2y, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*2,253*2,corr_thresh=.8, weight_bounds=(-.003,.03), cluster_u_coef=3, cluster_l_coef=-.03)

# %%
Portfolio_backtest(returns_opt_2y)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2002-01-09
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   514.41%
# CAGR﹪              12.03%
#
# Sharpe              0.94
# Prob. Sharpe Ratio  99.99%
# Sortino             1.34
# Sortino/√2          0.95
# Omega               1.18
#
# Max Drawdown        -45.31%
# Longest DD Days     1550
#
# Gain/Pain Ratio     0.18
# Gain/Pain (1M)      1.35
#
# Payoff Ratio        0.94
# Profit Factor       1.18
# Common Sense Ratio  1.14
# CPC Index           0.62
# Tail Ratio          0.97
# Outlier Win Ratio   3.37
# Outlier Loss Ratio  3.79
#
# MTD                 0.39%
# 3M                  9.3%
# 6M                  11.78%
# YTD                 28.16%
# 1Y                  28.03%
# 3Y (ann.)           11.64%
# 5Y (ann.)           15.24%
# 10Y (ann.)          8.74%
# All-time (ann.)     12.03%
#
# Avg. Drawdown       -1.61%
# Avg. Drawdown Days  24
# Recovery Factor     11.35
# Ulcer Index         0.14
# Serenity Index      1.13

# %% [markdown]
# ### 3 month prior and likelihood

# %%
returns_opt_3m, _ = Markowits_Bayes_Cluster_Rebalance(SP_train,21*3,253*2,21*3,corr_thresh=.8, weight_bounds=(-.003,.03), cluster_u_coef=3, cluster_l_coef=-.03)

# %%
Portfolio_backtest(returns_opt_3m)
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2002-01-09
# End Period          2017-12-29
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   401.83%
# CAGR﹪              10.62%
#
# Sharpe              0.79
# Prob. Sharpe Ratio  99.92%
# Sortino             1.12
# Sortino/√2          0.79
# Omega               1.16
#
# Max Drawdown        -47.13%
# Longest DD Days     1776
#
# Gain/Pain Ratio     0.16
# Gain/Pain (1M)      1.09
#
# Payoff Ratio        0.94
# Profit Factor       1.16
# Common Sense Ratio  1.05
# CPC Index           0.6
# Tail Ratio          0.9
# Outlier Win Ratio   3.44
# Outlier Loss Ratio  3.63
#
# MTD                 0.42%
# 3M                  10.14%
# 6M                  12.2%
# YTD                 24.28%
# 1Y                  23.44%
# 3Y (ann.)           15.23%
# 5Y (ann.)           17.71%
# 10Y (ann.)          8.66%
# All-time (ann.)     10.62%
#
# Avg. Drawdown       -1.84%
# Avg. Drawdown Days  26
# Recovery Factor     8.53
# Ulcer Index         0.15
# Serenity Index      0.78
